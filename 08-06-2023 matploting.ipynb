# %% [markdown]
# ## <u><center>Plotting with Matplotlib and Seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('./Car_sales.csv',parse_dates=['Latest_Launch'])
data
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
data.sort_values(by="Latest_Launch",inplace=True)
data
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 90       Mercury    Mountaineer              27.609               20.430
# 91       Mercury       Villager              20.380               14.795
# 110   Oldsmobile          Alero              80.255                  NaN
# 131       Saturn             SW               5.223               10.790
# 96    Mercedes-B            SLK               7.998                  NaN
# ..           ...            ...                 ...                  ...
# 133       Saturn             LS              49.989                  NaN
# 86       Mercury       Mystique              14.351                8.800
# 125      Porsche  Carrera Coupe               1.280               60.625
# 78       Lincoln      Navigator              22.925                  NaN
# 139       Toyota         Celica              33.269               15.445
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 157 entries, 90 to 139
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    datetime64[ns]
# ...

# %%
data.reset_index(drop=True,inplace=True)
data
# Out:
#     Manufacturer          Model  Sales_in_thousands  __year_resale_value  \
# 0        Mercury    Mountaineer              27.609               20.430
# 1        Mercury       Villager              20.380               14.795
# 2     Oldsmobile          Alero              80.255                  NaN
# 3         Saturn             SW               5.223               10.790
# 4     Mercedes-B            SLK               7.998                  NaN
# ..           ...            ...                 ...                  ...
# 152       Saturn             LS              49.989                  NaN
# 153      Mercury       Mystique              14.351                8.800
# 154      Porsche  Carrera Coupe               1.280               60.625
# 155      Lincoln      Navigator              22.925                  NaN
# 156       Toyota         Celica              33.269               15.445
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
data.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
data.isnull().mean()*100
# Out:
# Manufacturer            0.000000
# Model                   0.000000
# Sales_in_thousands      0.000000
# __year_resale_value    22.929936
# Vehicle_type            0.000000
# Price_in_thousands      1.273885
# Engine_size             0.636943
# Horsepower              0.636943
# Wheelbase               0.636943
# Width                   0.636943
# Length                  0.636943
# Curb_weight             1.273885
# Fuel_capacity           0.636943
# Fuel_efficiency         1.910828
# Latest_Launch           0.000000
# Power_perf_factor       1.273885
# dtype: float64

# %%
data.dropna(inplace=True)
data.drop_duplicates(inplace=True)

# %%
data["Year"]=data.Latest_Launch.dt.year
data["Month"]=data.Latest_Launch.dt.month
data["Day"]=data.Latest_Launch.dt.day
data.head(3)
# Out:
#   Manufacturer        Model  Sales_in_thousands  __year_resale_value  \
# 0      Mercury  Mountaineer              27.609               20.430
# 1      Mercury     Villager              20.380               14.795
# 3       Saturn           SW               5.223               10.790
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0          Car               27.56          4.0       210.0      111.6   70.2
# 1          Car               22.51          3.3       170.0      112.2   74.9
# 3    Passenger               14.29          1.9       124.0      102.4   66.4
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0   190.1        3.876           21.0             18.0    2008-02-13
# 1   194.7        3.944           20.0             21.0    2009-10-20
# 3   176.9        2.452           12.1             31.0    2011-01-15
#
#    Power_perf_factor  Year  Month  Day
# 0          85.949744  2008      2   13
# ...

# %%
data.drop(columns="Latest_Launch",inplace=True)

# %%
data.shape
# Out:
# (117, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 156
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         117 non-null    object
#  1   Model                117 non-null    object
#  2   Sales_in_thousands   117 non-null    float64
#  3   __year_resale_value  117 non-null    float64
#  4   Vehicle_type         117 non-null    object
#  5   Price_in_thousands   117 non-null    float64
#  6   Engine_size          117 non-null    float64
#  7   Horsepower           117 non-null    float64
#  8   Wheelbase            117 non-null    float64
#  9   Width                117 non-null    float64
#  10  Length               117 non-null    float64
#  11  Curb_weight          117 non-null    float64
#  12  Fuel_capacity        117 non-null    float64
#  13  Fuel_efficiency      117 non-null    float64
#  14  Power_perf_factor    117 non-null    float64
# ...

# %% [markdown]
# ### <u>Univariate Analysis

# %% [markdown]
# #### Histogram

# %%
sns.histplot(data=data,x="Sales_in_thousands")
plt.show()

# %% [markdown]
# #### Boxplot

# %%
sns.boxplot(data=data,y="Sales_in_thousands")
plt.show()

# %% [markdown]
# #### Kernel Density Estimation Plot(KDE)

# %%
sns.kdeplot(data=data.Sales_in_thousands)
plt.show()

# %% [markdown]
# #### <u>Subplot

# %%
# Subplot of histogram
sns.histplot(data=data)
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.xticks(rotation=95)
sns.boxplot(data=data)
plt.show()

# %%
sns.kdeplot(data=data)
plt.show()

# %% [markdown]
# ### <u><b>For Loop to plot subplot

# %%
#boxplot

for i in data.columns:
    if data[i].dtypes !="object":
        sns.boxplot(y=data[i])
    plt.show()

# %%
# histogram
for i in data.columns:
    if data[i].dtypes !='object':
        sns.histplot(x=data[i])   
    plt.show()

# %%
# kdeplot
for i in data.columns:
    if data[i].dtypes !='object':
        sns.kdeplot(data=data[i])
    plt.show()

# %% [markdown]
# ### <u> Subplots in matplotlib

# %%
plt.figure(figsize=(10,4))
plt.subplot(2,2,1)
sns.boxplot(data=data,y="Sales_in_thousands")

plt.figure(figsize=(10,4))
plt.subplot(2,2,2)
sns.boxplot(data=data,y='Price_in_thousands')

plt.figure(figsize=(10,4))
plt.subplot(2,2,3)
sns.boxplot(data=data,y='Engine_size')

plt.figure(figsize=(10,4))
plt.subplot(2,2,4)
sns.boxplot(data=data,y='Horsepower')

plt.show()

# %%
#subplot of histogram
plt.figure(figsize=(10,4))
plt.subplot(2,2,1)
sns.histplot(data=data,y="Sales_in_thousands")

plt.subplot(2,2,2)
sns.histplot(data=data,y='Price_in_thousands')

plt.subplot(2,2,3)
sns.histplot(data=data,y='Engine_size')

plt.subplot(2,2,4)
sns.histplot(data=data,y='Horsepower')

plt.show()

# %%
# subplot of kde
plt.figure(figsize=(10,5))
plt.subplot(2,2,1)
sns.kdeplot(data=data,y='Horsepower')

plt.subplot(2,2,2)
sns.kdeplot(data=data,y='Price_in_thousands')

plt.subplot(2,2,3)
sns.kdeplot(data=data,y='Engine_size')

plt.subplot(2,2,4)
sns.kdeplot(data=data,y='Sales_in_thousands')

plt.show()

# %% [markdown]
# ### <u>Subplot using Enumerate

# %%
feature= []

# %%
for i in data.columns:
    if data[i].dtypes !='object':
        feature.append(i)

# %%
feature
# Out:
# ['Sales_in_thousands',
#  '__year_resale_value',
#  'Price_in_thousands',
#  'Engine_size',
#  'Horsepower',
#  'Wheelbase',
#  'Width',
#  'Length',
#  'Curb_weight',
#  'Fuel_capacity',
#  'Fuel_efficiency',
#  'Power_perf_factor',
#  'Year',
#  'Month',
#  'Day']

# %%
list(enumerate(feature))
# Out:
# [(0, 'Sales_in_thousands'),
#  (1, '__year_resale_value'),
#  (2, 'Price_in_thousands'),
#  (3, 'Engine_size'),
#  (4, 'Horsepower'),
#  (5, 'Wheelbase'),
#  (6, 'Width'),
#  (7, 'Length'),
#  (8, 'Curb_weight'),
#  (9, 'Fuel_capacity'),
#  (10, 'Fuel_efficiency'),
#  (11, 'Power_perf_factor'),
#  (12, 'Year'),
#  (13, 'Month'),
#  (14, 'Day')]

# %%
#boxplot
plt.figure(figsize=(13,10))
for i in enumerate(feature):
    plt.subplot(5,3,i[0]+1)
    sns.boxplot(data=data,y=i[1],color="green")

# %%
data.rename(columns={'__year_resale_value':'Year_resale_value'},inplace=True)
data.head(3)
# Out:
#   Manufacturer        Model  Sales_in_thousands  Year_resale_value  \
# 0      Mercury  Mountaineer              27.609             20.430
# 1      Mercury     Villager              20.380             14.795
# 3       Saturn           SW               5.223             10.790
#
#   Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# 0          Car               27.56          4.0       210.0      111.6   70.2
# 1          Car               22.51          3.3       170.0      112.2   74.9
# 3    Passenger               14.29          1.9       124.0      102.4   66.4
#
#    Length  Curb_weight  Fuel_capacity  Fuel_efficiency  Power_perf_factor  \
# 0   190.1        3.876           21.0             18.0          85.949744
# 1   194.7        3.944           20.0             21.0          69.671461
# 3   176.9        2.452           12.1             31.0          49.865774
#
#    Year  Month  Day
# 0  2008      2   13
# 1  2009     10   20
# ...

# %% [markdown]
# ### Line charts

# %%
plt.figure(figsize=(10,6))
plt.xlabel=("Year resale value")
plt.ylabel=('Price')
plt.title("Car_sales")
sns.lineplot(data=data,x='Year_resale_value',y='Price_in_thousands')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.xlabel=("Horsepower")
plt.ylabel=('Year_resale_value')
plt.title("Car_sales")
sns.lineplot(data=data,x='Horsepower',y='Year_resale_value',color='purple')
plt.show()

# %% [markdown]
# ### Countplot

# %%
plt.figure(figsize=(10,5))
plt.xticks(rotation =67)

sns.countplot(data=data,x='Manufacturer')
plt.show()

# %% [markdown]
# ### Area chart

# %%
plt.figure(figsize=(16,5))
plt.xticks(rotation=79)
plt.stackplot(data.Manufacturer,data.Sales_in_thousands)
plt.show()

# %%
plt.figure(figsize=(18,5))
plt.xticks(rotation=87)
plt.stackplot(data.Year,data.Manufacturer)
plt.show()

# %%
plt.figure(figsize=(18,5))
plt.xticks(rotation=88)
plt.stackplot(data.Manufacturer,data.Sales_in_thousands,data.Price_in_thousands)
plt.show()
