# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('./titanic.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
data.drop(columns="Ticket",inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### Histogram

# %%
# Histplot of Fare
sns.histplot(data=data,x="Fare")
plt.show()

# %%
# Histplot of Survived
sns.histplot(data=data,x='Survived')
plt.show()

# %%
sns.histplot(data=data,x='Pclass')
plt.show()

# %% [markdown]
# #### Boxplot

# %%
sns.boxplot(data=data,x='Age')
plt.show()

# %%
sns.boxplot(data=data,y='Age')
# Out:
# <AxesSubplot:ylabel='Age'>

# %%
sns.boxplot(data=data,y='Fare')
plt.show()

# %% [markdown]
# ### <b>Kernel Density Estimation Plot(KDE Plot)

# %%
sns.kdeplot(data=data.Age)
plt.show()

# %% [markdown]
# ### <b>Subplot

# %%
sns.histplot(data=data)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation= 90)
sns.boxplot(data=data)
plt.show()

# %%
sns.kdeplot(data=data)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(3,3,1)
sns.boxplot(data=data,x="Fare")

plt.figure(figsize=(10,5))
plt.subplot(3,3,2)
sns.boxplot(data=data,x="Survived")

plt.figure(figsize=(10,5))
plt.subplot(3,3,3)
sns.boxplot(data=data,x="Pclass")

plt.figure(figsize=(10,5))
plt.subplot(3,3,4)
sns.boxplot(data=data,x="Age")

plt.figure(figsize=(10,5))
plt.subplot(3,3,5)
sns.boxplot(data=data,x="SibSp")

plt.figure(figsize=(10,5))
plt.subplot(3,3,6)
sns.boxplot(data=data,x='Parch')

plt.show()

# %% [markdown]
# ### countplot

# %%
sns.countplot(data=data,x='Survived',hue="Sex")
plt.show()

# %%
sns.countplot(data=data,x="Survived",hue="Pclass")
plt.show()

# %%
sns.countplot(data=data,x='SibSp',hue="Sex")
plt.show()

# %%
sns.countplot(x="Parch",data=data,hue="Pclass")
plt.show()

# %%
sns.countplot(data=data,x="Embarked",hue="Sex")
plt.show()

# %%
sns.countplot(data=data,x="Embarked",hue="Pclass")
plt.show()

# %% [markdown]
# ### Barplot

# %%
sns.barplot(data=data,x='Pclass',y='Age')
plt.show()

# %%
sns.barplot(data=data,x="Pclass",y="Age",hue="Sex")
plt.show()

# %%
sns.barplot(data=data,x="Pclass",y="Age",hue="Embarked")
plt.show()

# %% [markdown]
# ### Piechart

# %%
Sib_Sp_Fare=data.groupby(['SibSp'])["Fare"].sum()
Sib_Sp_Fare.plot.pie(legend=True,autopct='%1.2f%%')
plt.show()

# %%
embarked_fare=data.groupby(['Embarked'])['Fare'].sum()

# %%
embarked_fare.plot.pie(legend=True,autopct= '%1.2f%%')
# Out:
# <AxesSubplot:ylabel='Fare'>

# %%
embarked_fare_mean=data.groupby(['Embarked'])['Fare'].mean()

# %%
embarked_fare_mean.plot.bar()
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
sns.scatterplot(x='Age',y='Fare',data=data)
plt.show()

# %%
sns.scatterplot(data=data,x='Age',y='Fare',hue='Sex')
plt.show()

# %%
sns.scatterplot(data=data,x='Age',y='Fare',hue='Pclass')
plt.show()

# %%
sns.scatterplot(data=data,x='Age',y='Fare',size='Pclass')
plt.show()

# %%
sns.scatterplot(data=data,x='Age',y='Fare',size='Pclass',hue='Sex')
plt.show()

# %% [markdown]
# ### regplot

# %%
sns.regplot(x='Age',y='Fare',data=data)
plt.show()

# %% [markdown]
# ###  Details of Embarked from c

# %%
embarked_c=data.query("Embarked=='C'")

# %%
embarked_c
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 9             10         1       2
# 19            20         1       3
# 26            27         0       3
# 30            31         0       1
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 26                             Emir, Mr. Farred Chehab    male   NaN      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt.figure(figsize=(10,6))
plt.xlabel('Survived')
plt.ylabel('Pclass')
plt.title("no.of people Survived in Pclass Embarked from C")
sns.lineplot(data=embarked_c,x='Survived',y='Pclass')
plt.show()

# %% [markdown]
# #### countplot

# %%
plt.figure(figsize=(9,4))
plt.xticks(rotation=90)
sns.countplot(data=embarked_c,x='Survived',hue="Sex")
plt.show()

# %%
plt.figure(figsize=(7,3))
plt.xticks(rotation=90)
sns.countplot(data=embarked_c,x='Pclass',hue="Sex")
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.xticks(rotation=90)
sns.countplot(data=embarked_c,x='Age',hue="Sex")
plt.show()
