# %% [markdown]
# ## <b><center><u> Climate dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('./climate_change_data.csv',parse_dates=["Date"])
data
# Out:
#                               Date           Location                Country  \
# 0    2000-01-01 00:00:00.000000000    New Williamtown                 Latvia
# 1    2000-01-01 20:09:43.258325832       North Rachel           South Africa
# 2    2000-01-02 16:19:26.516651665   West Williamland          French Guiana
# 3    2000-01-03 12:29:09.774977497        South David                Vietnam
# 4    2000-01-04 08:38:53.033303330     New Scottburgh                Moldova
# ...                            ...                ...                    ...
# 9995 2022-12-27 15:21:06.966696576   South Elaineberg                 Bhutan
# 9996 2022-12-28 11:30:50.225022464       Leblancville                  Congo
# 9997 2022-12-29 07:40:33.483348224     West Stephanie              Argentina
# 9998 2022-12-30 03:50:16.741674112        Port Steven                Albania
# 9999 2022-12-31 00:00:00.000000000  West Anthonyburgh  Sao Tome and Principe
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            10000 non-null  datetime64[ns]
#  1   Location        10000 non-null  object
#  2   Country         10000 non-null  object
#  3   Temperature     10000 non-null  float64
#  4   CO2 Emissions   10000 non-null  float64
#  5   Sea Level Rise  10000 non-null  float64
#  6   Precipitation   10000 non-null  float64
#  7   Humidity        10000 non-null  float64
#  8   Wind Speed      10000 non-null  float64
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 703.2+ KB

# %%
data["Time"]=data.Date.dt.time
data['Year']=data.Date.dt.year
data['Month']=data.Date.dt.month
data['Day']=data.Date.dt.day

# %%
data.head()
# Out:
#                            Date          Location        Country  Temperature  \
# 0 2000-01-01 00:00:00.000000000   New Williamtown         Latvia    10.688986
# 1 2000-01-01 20:09:43.258325832      North Rachel   South Africa    13.814430
# 2 2000-01-02 16:19:26.516651665  West Williamland  French Guiana    27.323718
# 3 2000-01-03 12:29:09.774977497       South David        Vietnam    12.309581
# 4 2000-01-04 08:38:53.033303330    New Scottburgh        Moldova    13.210885
#
#    CO2 Emissions  Sea Level Rise  Precipitation   Humidity  Wind Speed  \
# 0     403.118903        0.717506      13.835237  23.631256   18.492026
# 1     396.663499        1.205715      40.974084  43.982946   34.249300
# 2     451.553155       -0.160783      42.697931  96.652600   34.124261
# 3     422.404983       -0.475931       5.193341  47.467938    8.554563
# 4     410.472999        1.135757      78.695280  61.789672    8.001164
#
#               Time  Year  Month  Day
# ...

# %%
data.drop(columns="Date",inplace=True)
data.head()
# Out:
#            Location        Country  Temperature  CO2 Emissions  \
# 0   New Williamtown         Latvia    10.688986     403.118903
# 1      North Rachel   South Africa    13.814430     396.663499
# 2  West Williamland  French Guiana    27.323718     451.553155
# 3       South David        Vietnam    12.309581     422.404983
# 4    New Scottburgh        Moldova    13.210885     410.472999
#
#    Sea Level Rise  Precipitation   Humidity  Wind Speed             Time  \
# 0        0.717506      13.835237  23.631256   18.492026         00:00:00
# 1        1.205715      40.974084  43.982946   34.249300  20:09:43.258325
# 2       -0.160783      42.697931  96.652600   34.124261  16:19:26.516651
# 3       -0.475931       5.193341  47.467938    8.554563  12:29:09.774977
# 4        1.135757      78.695280  61.789672    8.001164  08:38:53.033303
#
#    Year  Month  Day
# 0  2000      1    1
# 1  2000      1    1
# 2  2000      1    2
# 3  2000      1    3
# 4  2000      1    4

# %%
data.Country.unique()
# Out:
# array(['Latvia', 'South Africa', 'French Guiana', 'Vietnam', 'Moldova',
#        'Saint Helena', 'Tuvalu', 'Australia', 'Qatar', 'Chad', 'Fiji',
#        'Guernsey', 'Egypt', 'Rwanda', 'Samoa', 'Mongolia',
#        'Equatorial Guinea', 'Libyan Arab Jamahiriya', 'Mali',
#        'Cocos (Keeling) Islands', 'Bahrain',
#        'French Southern Territories', 'Iceland', 'Tajikistan',
#        'Norfolk Island', 'Bosnia and Herzegovina', 'Reunion', 'Ethiopia',
#        'Spain', 'Italy', 'Andorra', 'Gibraltar', 'Monaco', 'Comoros',
#        'British Indian Ocean Territory (Chagos Archipelago)',
#        'Czech Republic', 'Iran', 'Antigua and Barbuda', 'Seychelles',
#        'Slovenia', 'Gabon', 'India', 'Congo', 'Tunisia', 'Costa Rica',
#        'Cuba', 'Grenada', 'Suriname', 'Brunei Darussalam',
#        'United States of America', 'Israel', 'Georgia', 'Cape Verde',
#        'Ukraine', 'Colombia', 'Guyana', 'Estonia', 'Cambodia', 'Maldives',
# ...

# %% [markdown]
# ### Is India included in  this dataset

# %%
Ind =data.query("Country=='India'")

# %%
Ind
# Out:
#                   Location Country  Temperature  CO2 Emissions  \
# 44             Stewartbury   India    13.863784     408.121863
# 153             Port Jesus   India    14.563792     441.458510
# 420           Lake Heather   India     8.050407     352.500027
# 604        Port Haydentown   India    12.435437     380.040060
# 626             Marisafort   India    19.580143     412.246774
# 754              Jacobland   India    18.290347     312.602899
# 764    South Kimberlyshire   India    12.013457     334.323596
# 1437             New David   India     8.794670     352.886364
# 2589      South Robertstad   India    18.649079     417.644878
# 2805            Bowersfurt   India    15.702748     462.738893
# 3217            Aliciaview   India    17.222168     342.906534
# 3403      North Laurieside   India    15.904627     354.901698
# 3548           Francisberg   India    19.211249     352.322940
# 3555             Masonfort   India    15.391247     449.799677
# ...

# %%
Ind.value_counts().sum()
# Out:
# 36

# %% [markdown]
# ### Is Nepal included in this dataset

# %%
nepal =data.query('Country=="Nepal"')

# %%
nepal
# Out:
#                Location Country  Temperature  CO2 Emissions  Sea Level Rise  \
# 351         Maxwellview   Nepal     8.297901     467.913863       -0.025501
# 418        Stewartburgh   Nepal    14.976462     440.897596        0.006773
# 530          New Joseph   Nepal    13.464401     360.947713        0.247618
# 753          Lesliefurt   Nepal    12.609260     370.439703       -0.174736
# 886         Sheltontown   Nepal    17.078840     412.419802        0.237934
# 939         Edwardsside   Nepal    12.386657     401.679947       -0.948355
# 2108     Lake Dylanfort   Nepal    21.045265     401.537458        1.404937
# 2372          Port Lisa   Nepal     9.200413     372.547461        0.504794
# 2383        Port Thomas   Nepal    21.143162     327.881658        0.754626
# 2771        North Julie   Nepal    13.409898     379.931778        1.062849
# 2974         North Cory   Nepal     5.321296     421.206745       -0.334704
# ...

# %% [markdown]
# ### Is there any Location called Stewartburgh

# %%
port =data.query("Location=='Stewartburgh'")
port
# Out:
#          Location Country  Temperature  CO2 Emissions  Sea Level Rise  \
# 418  Stewartburgh   Nepal    14.976462     440.897596        0.006773
#
#      Precipitation   Humidity  Wind Speed             Time  Year  Month  Day
# 418       2.268688  85.152642   42.927492  03:43:21.980198  2000     12   17

# %%
data.Country.nunique()
# Out:
# 243

# %% [markdown]
# ### 10 Countries with less Humidity

# %%
data.nsmallest(10,"Humidity")
# Out:
#              Location                                       Country  \
# 8939    Thompsonshire                          Netherlands Antilles
# 6143       West Frank  Antarctica (the territory South of 60 deg S)
# 1158        Jasonfurt                                      Cameroon
# 8864       West Sarah                                         Niger
# 9397     Lake Cynthia                                  Burkina Faso
# 8115       Port Aaron                                          Fiji
# 4250        Burnsview                                       Liberia
# 9477       West Allen                                         Chile
# 5392         Amymouth                                      Dominica
# 8191  North Joshuaton                                 French Guiana
#
#       Temperature  CO2 Emissions  Sea Level Rise  Precipitation  Humidity  \
# 8939    15.442304     450.401730        0.072736       5.094774  0.018998
# ...

# %% [markdown]
# ### Country with high Humidity

# %%
data.nlargest(1,"Humidity")
# Out:
#          Location  Country  Temperature  CO2 Emissions  Sea Level Rise  \
# 2869  West Ashley  Finland    17.711044     486.118907       -0.639723
#
#       Precipitation   Humidity  Wind Speed             Time  Year  Month  Day
# 2869      30.779914  99.959665   34.390077  04:49:28.136813  2006      8    7

# %% [markdown]
# ### Country with high Temperature

# %%
data.nlargest(1,"Temperature")
# Out:
#          Location Country  Temperature  CO2 Emissions  Sea Level Rise  \
# 5601  Bradleyport   Niger    33.976956     370.009529       -1.173126
#
#       Precipitation   Humidity  Wind Speed             Time  Year  Month  Day
# 5601      53.160033  47.798918    16.57178  07:27:09.882988  2012     11   18

# %% [markdown]
# ### Country with Low Temperature

# %%
data.nsmallest(1,'Temperature')
# Out:
#          Location        Country  Temperature  CO2 Emissions  Sea Level Rise  \
# 7663  East Edward  Liechtenstein    -3.803589     350.546781       -0.875512
#
#       Precipitation   Humidity  Wind Speed             Time  Year  Month  Day
# 7663      17.935275  79.957867    7.698461  13:31:48.550855  2017      8   16

# %%
sns.histplot(data=data,x='Temperature')
plt.show()

# %% [markdown]
# ### Countries Temperature in Year

# %%
country_temp =pd.crosstab(index=data.Country, columns=data.Year, values=data.Temperature, aggfunc='sum', margins=True)

# %%
country_temp
# Out:
# Year                   2000         2001         2002         2003  \
# Country
# Afghanistan       32.495836    27.435392     2.193931    49.673945
# Albania           11.968125    41.655752    32.502228    20.715624
# Algeria           40.245465    13.723152    25.468400    43.720834
# American Samoa    26.985341    46.380649     7.490023    15.275581
# Andorra           20.563356    31.169867     4.499491    75.120818
# ...                     ...          ...          ...          ...
# Western Sahara    43.913913    36.754077    49.386363    30.377745
# Yemen             21.831419    13.653826    18.632904    39.523905
# Zambia                  NaN    31.646733    45.187000    35.629587
# Zimbabwe          71.567356    35.654582    24.876040          NaN
# All             6553.031463  6499.539539  6350.330130  6593.133673
#
# Year                   2004         2005         2006         2007  \
# Country
# Afghanistan       46.983613    38.944595    16.087604    13.790531
# ...

# %% [markdown]
# ## India

# %%
plt.figure(figsize=(10,6))
plt.xlabel("Year")
plt.ylabel("Temperature")
plt.title("India's Temperature according to Year")
sns.lineplot(data=Ind,x='Year',y="Temperature")
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.xlabel("Humidity")
plt.ylabel("Temperature")
plt.title("India's Temperature&Humidity")
sns.lineplot(data=Ind,x='Humidity',y="Temperature")
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.xlabel("Year")
plt.ylabel("Sea Level Rise")
plt.title("India's SeaLevel Rise in Years")
sns.lineplot(data=Ind,x='Year',y="Sea Level Rise")
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.xlabel("Year")
plt.ylabel("Wind Speed")
plt.title("India's WindSpeed in Years")
sns.lineplot(data=Ind,x='Year',y="Wind Speed")
plt.show()

# %%
plt.figure(figsize=(9,4))
plt.xticks(rotation=76)
sns.boxplot(data=Ind,x='Wind Speed')
plt.show()

# %%
plt.figure(figsize=(11,6))
plt.xticks(rotation=78)
sns.boxplot(data=Ind,x="CO2 Emissions")
plt.show()

# %%
sns.histplot(data=Ind,x="Wind Speed")
plt.show()

# %%
sns.histplot(data=Ind,x='Sea Level Rise');

# %%
sns.kdeplot(data=Ind.Temperature)
plt.show()

# %%
sns.kdeplot(data=Ind.Precipitation)
plt.show()

# %%
sns.kdeplot(data=Ind.Humidity)
plt.show()

# %% [markdown]
# ### Subplot of India

# %%
sns.histplot(data=Ind)
plt.show()

# %%
plt.figure(figsize=(9,4))
plt.xticks(rotation=59)
sns.boxplot(data=Ind)
plt.show()

# %%
sns.kdeplot(data=Ind)
plt.show()

# %% [markdown]
# ### Subplot in matlibplot of India

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,3,1)
sns.boxplot(data=Ind,y='Humidity')

plt.figure(figsize=(10,6))
plt.subplot(2,3,2)
sns.boxplot(data=Ind,y='Wind Speed')

plt.figure(figsize=(10,6))
plt.subplot(2,3,3)
sns.boxplot(data=Ind,y='Sea Level Rise')

plt.figure(figsize=(10,6))
plt.subplot(2,3,4)
sns.boxplot(data=Ind,y='Temperature')

plt.figure(figsize=(10,6))
plt.subplot(2,3,5)
sns.boxplot(data=Ind,y='CO2 Emissions')

plt.figure(figsize=(10,6))
plt.subplot(2,3,6)
sns.boxplot(data=Ind,y='Precipitation')

plt.show();

# %%
plt.figure(figsize=(10,4))
plt.subplot(2,3,1)
sns.histplot(data=Ind,x='Precipitation')

plt.figure(figsize=(10,4))
plt.subplot(2,3,2)
sns.histplot(data=Ind,x="Humidity")

plt.figure(figsize=(10,4))
plt.subplot(2,3,3)
sns.histplot(data=Ind,x="Temperature")

plt.figure(figsize=(10,4))
plt.subplot(2,3,4)
sns.histplot(data=Ind,x="Wind Speed")

plt.figure(figsize=(10,4))
plt.subplot(2,3,5)
sns.histplot(data=Ind,x='CO2 Emissions')

plt.figure(figsize=(10,4))
plt.subplot(2,3,6)
sns.histplot(data=Ind,x="Sea Level Rise")
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,3,1)
sns.kdeplot(data=Ind,x='Humidity')

plt.figure(figsize=(10,6))
plt.subplot(2,3,2)
sns.kdeplot(data=Ind,x='Wind Speed')

plt.figure(figsize=(10,6))
plt.subplot(2,3,3)
sns.kdeplot(data=Ind,x='Sea Level Rise')

plt.figure(figsize=(10,6))
plt.subplot(2,3,4)
sns.kdeplot(data=Ind,x='Temperature')

plt.figure(figsize=(10,6))
plt.subplot(2,3,5)
sns.kdeplot(data=Ind,x='CO2 Emissions')

plt.figure(figsize=(10,6))
plt.subplot(2,3,6)
sns.kdeplot(data=Ind,x='Precipitation')

plt.show();

# %% [markdown]
# ### Areaplot of India

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=98)
plt.stackplot(Ind.Location,Ind.Humidity,Ind.Temperature,Ind.Month)
plt.show()

# %%
sns.scatterplot(data=Ind,x="Location",y="Sea Level Rise")
plt.xticks(rotation=90)
plt.show()

# %%
sns.pairplot(data=Ind)
plt.show()

# %% [markdown]
# ### Pairplot of Nepal

# %%
sns.pairplot(data=nepal)
plt.show()

# %%
sns.heatmap(Ind.corr(),annot=True)
plt.show()

# %% [markdown]
# ### Horizontal bar

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=88)
sns.barplot(data=Ind,x="Location",y="Humidity")
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=88)
sns.barplot(data=nepal,x="Location",y="Humidity")
plt.show()
