# %% [markdown]
# ## <i><u><center>Outlier Treatment Method

# %% [markdown]
# ### <i>Importing libraries

# %%
import pandas as pd
import numpy as np
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### <i> Importing dataset

# %%
data = pd.read_csv("./CarPricesData.csv")
data
# Out:
#       Price   Age     KM FuelType   HP  MetColor  Automatic      CC  Doors  \
# 0     13500  23.0  46986   Diesel   90         1          0  2000.0      3
# 1     13750  23.0  72937   Diesel   90         1          0  2000.0      3
# 2     13950  24.0  41711   Diesel   90         1          0  2000.0      3
# 3     14950  26.0  48000   Diesel   90         0          0  2000.0      3
# 4     13750  30.0  38500   Diesel   90         0          0  2000.0      3
# ...     ...   ...    ...      ...  ...       ...        ...     ...    ...
# 1431   7500  69.0  20544   Petrol   86         1          0  1300.0      3
# 1432  10845  72.0  19000   Petrol   86         0          0  1300.0      3
# 1433   8500  71.0  17016   Petrol   86         0          0  1300.0      3
# 1434   7250  70.0  16916   Petrol   86         1          0  1300.0      3
# 1435   6950  76.0      1   Petrol  110         0          0  1600.0      5
#
#       Weight
# 0     1165.0
# 1     1165.0
# 2     1165.0
# ...

# %% [markdown]
# ### <li><i> Z-score Method

# %%
sns.boxplot(data = data,y ='Price')
plt.show()

# %%
data['z_score'] = stats.zscore(data.Price)

# %%
data.head()
# Out:
#    Price   Age     KM FuelType  HP  MetColor  Automatic      CC  Doors  \
# 0  13500  23.0  46986   Diesel  90         1          0  2000.0      3
# 1  13750  23.0  72937   Diesel  90         1          0  2000.0      3
# 2  13950  24.0  41711   Diesel  90         1          0  2000.0      3
# 3  14950  26.0  48000   Diesel  90         0          0  2000.0      3
# 4  13750  30.0  38500   Diesel  90         0          0  2000.0      3
#
#    Weight   z_score
# 0  1165.0  0.763763
# 1  1165.0  0.832715
# 2  1165.0  0.887877
# 3  1165.0  1.163685
# 4  1170.0  0.832715

# %%
cleaned_data = data[data['z_score']<3]
cleaned_data
# Out:
#       Price   Age     KM FuelType   HP  MetColor  Automatic      CC  Doors  \
# 0     13500  23.0  46986   Diesel   90         1          0  2000.0      3
# 1     13750  23.0  72937   Diesel   90         1          0  2000.0      3
# 2     13950  24.0  41711   Diesel   90         1          0  2000.0      3
# 3     14950  26.0  48000   Diesel   90         0          0  2000.0      3
# 4     13750  30.0  38500   Diesel   90         0          0  2000.0      3
# ...     ...   ...    ...      ...  ...       ...        ...     ...    ...
# 1431   7500  69.0  20544   Petrol   86         1          0  1300.0      3
# 1432  10845  72.0  19000   Petrol   86         0          0  1300.0      3
# 1433   8500  71.0  17016   Petrol   86         0          0  1300.0      3
# 1434   7250  70.0  16916   Petrol   86         1          0  1300.0      3
# 1435   6950  76.0      1   Petrol  110         0          0  1600.0      5
#
#       Weight   z_score
# 0     1165.0  0.763763
# ...

# %%
sns.boxplot(data= cleaned_data,y = 'Price')
plt.show()

# %% [markdown]
# ### <i><li> Percentile Capping Method

# %%
lower = np.percentile(data.Price,5)
upper = np.percentile(data.Price,95)

# %%
cleaned_data = np.clip(data.Price,lower,upper)
cleaned_data
# Out:
# 0       13500
# 1       13750
# 2       13950
# 3       14950
# 4       13750
#         ...
# 1431     7500
# 1432    10845
# 1433     8500
# 1434     7250
# 1435     6950
# Name: Price, Length: 1436, dtype: int64

# %%
data1 = data[data["Price"]== cleaned_data]

# %%
data.shape
# Out:
# (1436, 11)

# %%
data1.shape
# Out:
# (1308, 11)

# %%
sns.boxplot(data = data1 ,y = 'Price')
plt.show()

# %% [markdown]
# ### <i><li> Winsorization

# %%
import scipy.stats as statis

# %%
winsorization_price = statis.mstats.winsorize(data.Price,limits=[0.05,0.05])
winsorization_price
# Out:
# masked_array(data=[13500, 13750, 13950, ...,  8500,  7250,  6950],
#              mask=False,
#        fill_value=999999,
#             dtype=int64)

# %%
data['winsorization_price'] = winsorization_price

# %%
data
# Out:
#       Price   Age     KM FuelType   HP  MetColor  Automatic      CC  Doors  \
# 0     13500  23.0  46986   Diesel   90         1          0  2000.0      3
# 1     13750  23.0  72937   Diesel   90         1          0  2000.0      3
# 2     13950  24.0  41711   Diesel   90         1          0  2000.0      3
# 3     14950  26.0  48000   Diesel   90         0          0  2000.0      3
# 4     13750  30.0  38500   Diesel   90         0          0  2000.0      3
# ...     ...   ...    ...      ...  ...       ...        ...     ...    ...
# 1431   7500  69.0  20544   Petrol   86         1          0  1300.0      3
# 1432  10845  72.0  19000   Petrol   86         0          0  1300.0      3
# 1433   8500  71.0  17016   Petrol   86         0          0  1300.0      3
# 1434   7250  70.0  16916   Petrol   86         1          0  1300.0      3
# 1435   6950  76.0      1   Petrol  110         0          0  1600.0      5
#
#       Weight   z_score  winsorization_price
# ...

# %%
sns.boxplot(y = data.winsorization_price)
plt.show()

# %%
sns.boxplot(y =data.Price, color = 'Grey')
plt.show()
