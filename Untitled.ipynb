# %%
import pandas as pd

# %%
data =pd.read_csv("./titanic.csv")

# %% [markdown]
# ### Head

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... Embarked WikiId  \
# 0      0         A/5 21171   7.2500  ...        S  691.0
# 1      0          PC 17599  71.2833  ...        C   90.0
# 2      0  STON/O2. 3101282   7.9250  ...        S  865.0
# 3      0            113803  53.1000  ...        S  127.0
# ...

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
# 5            6       0.0       3
# 6            7       0.0       1
# 7            8       0.0       3
# 8            9       1.0       3
# 9           10       1.0       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
data.tail(10)
# Out:
#       PassengerId  Survived  Pclass  \
# 1299         1300       NaN       3
# 1300         1301       NaN       3
# 1301         1302       NaN       3
# 1302         1303       NaN       1
# 1303         1304       NaN       3
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1299                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 1300                        Peacock, Miss. Treasteall  female   3.0      1
# 1301                           Naughton, Miss. Hannah  female   NaN      0
# 1302  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 1303                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 1304                               Spector, Mr. Woolf    male   NaN      0
# ...

# %%
data.sample(20)
# Out:
#       PassengerId  Survived  Pclass  \
# 702           703       0.0       3
# 1082         1083       NaN       1
# 241           242       1.0       3
# 1088         1089       NaN       3
# 252           253       0.0       1
# 957           958       NaN       3
# 396           397       0.0       3
# 1282         1283       NaN       1
# 275           276       1.0       1
# 632           633       1.0       1
# 481           482       0.0       2
# 1011         1012       NaN       2
# 139           140       0.0       1
# 1069         1070       NaN       2
# 1055         1056       NaN       2
# 41             42       0.0       2
# 727           728       1.0       3
# 593           594       0.0       3
# 1114         1115       NaN       3
# 384           385       0.0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 702                               Barbara, Miss. Saiide  female  18.0      0
# ...

# %%
data.shape
# Out:
# (1309, 21)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  WikiId       1304 non-null   float64
#  13  Name_wiki    1304 non-null   object
#  14  Age_wiki     1302 non-null   float64
#  15  Hometown     1304 non-null   object
#  16  Boarded      1304 non-null   object
#  17  Destination  1304 non-null   object
# ...

# %%
data.describe() .T
# Out:
#               count        mean         std   min       25%       50%  \
# PassengerId  1309.0  655.000000  378.020061  1.00  328.0000  655.0000
# Survived      891.0    0.383838    0.486592  0.00    0.0000    0.0000
# Pclass       1309.0    2.294882    0.837836  1.00    2.0000    3.0000
# Age          1046.0   29.881138   14.413493  0.17   21.0000   28.0000
# SibSp        1309.0    0.498854    1.041658  0.00    0.0000    0.0000
# Parch        1309.0    0.385027    0.865560  0.00    0.0000    0.0000
# Fare         1308.0   33.295479   51.758668  0.00    7.8958   14.4542
# WikiId       1304.0  658.534509  380.377373  1.00  326.7500  661.5000
# Age_wiki     1302.0   29.415829   13.758954  0.17   21.0000   28.0000
# Class        1304.0    2.291411    0.840852  1.00    1.7500    3.0000
#
#                  75%        max
# PassengerId  982.000  1309.0000
# Survived       1.000     1.0000
# Pclass         3.000     3.0000
# Age           39.000    80.0000
# ...

# %%
data.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# WikiId            5
# Name_wiki         5
# Age_wiki          7
# Hometown          5
# Boarded           5
# Destination       5
# Lifeboat        807
# Body           1179
# Class             5
# dtype: int64

# %% [markdown]
# ### Null percentage

# %%
data.isnull()mean()*100
# Out:
#   File "C:\Users\USER\AppData\Local\Temp\ipykernel_128\3183343213.py", line 1
#     data.isnull()mean()*100
#                  ^
# SyntaxError: invalid syntax

# %%
data.isnull().mean()*100

# %% [markdown]
# ### Dropping the columns

# %%
data.drop(columns=['Body', 'Lifeboat', 'Cabin', 'PassengerId' ])

# %%
data

# %%
data.drop(columns=['Body', 'Lifeboat', 'Cabin', 'PassengerId'], inplace=True)

# %%
data

# %%
data.Pclass.unique()

# %%
data.Sex.value_counts()

# %%
data.Embarked.unique()

# %% [markdown]
# ### filling nan values

# %%
data.Embarked.value_counts()

# %%
data.Embarked.fillna("S", inplace=True)

# %%
data.isnull().sum()

# %%
fare_mean= data.Fare.mean()
fare_mean

# %%
data.Fare.fillna(fare_mean, inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# WikiId            5
# Name_wiki         5
# Age_wiki          7
# Hometown          5
# Boarded           5
# Destination       5
# Lifeboat        807
# Body           1179
# Class             5
# dtype: int64

# %%
data.Age.value_counts()

# %%
data.Age.fillna(24.0, inplace=True)

# %%
data.isnull().sum()

# %%
data.drop(columns=['WikiId', 'Name_wiki', 'Age_wiki'], inplace=True)

# %%
data

# %%
data.isnull().sum()

# %%
data.Destination

# %%
data.Destination
# Out:
# 0       Qu'Appelle Valley, Saskatchewan, Canada
# 1                        New York, New York, US
# 2                                 New York City
# 3                   Scituate, Massachusetts, US
# 4                                 New York City
#                          ...
# 1304                              New York City
# 1305                     New York, New York, US
# 1306                                         US
# 1307                              New York City
# 1308                      Detroit, Michigan, US
# Name: Destination, Length: 1309, dtype: object

# %%
data.Destination.value_counts()

# %%
data.Destination.isnull().sum()

# %%
data.Destination.value_counts()

# %%
data.Destination.fillna("New York City", inplace=True)

# %%
data.Destination

# %%
data.isnull().sum()

# %%
Survived_mean= data.Survived.mean()
Survived_mean

# %%
Class_mode= data.Class.mode()
Class_mode

# %%
data.Class.isnull().sum()

# %%
data.Class

# %%
data.Class.fillna(3.0, inplace=True)

# %%
data.Class

# %%
data.Class.isnull().sum()

# %%
data.isnull().sum()

# %%
data.Boarded

# %%
data.Boarded.isnull().sum()

# %%
data.Boarded.fillna("Cherbourg", inplace=True)

# %%
data.Boarded

# %%
data.Boarded.isnull().sum()

# %%
data.isnull().sum()

# %%
data.Hometown

# %%
data.Hometown.fillna("Jyväskylä, Finland", inplace=True)

# %%
data.Hometown.isnull().sum()

# %%
data.isnull().sum()

# %%
data

# %% [markdown]
# ### Groupby

# %%
sex_survived = data.groupby(["Sex"])["Survived"].sum()

# %%
sex_survived
# Out:
# Sex
# female    233.0
# male      109.0
# Name: Survived, dtype: float64

# %%
data
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
P_class_Boarded = data.query("Boarded == 'Southampton'")

# %%
P_class_Boarded
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# 6               7       0.0       1
# ...           ...       ...     ...
# 1302         1303       NaN       1
# 1303         1304       NaN       3
# 1304         1305       NaN       3
# 1306         1307       NaN       3
# 1307         1308       NaN       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# ...

# %%
sex_boarder = data.groupby(["Sex"])["Boarded"].sum()

# %%
sex_boarder
# Out:
# Sex
# female    CherbourgSouthamptonSouthamptonSouthamptonCher...
# male      SouthamptonSouthamptonQueenstownSouthamptonSou...
# Name: Boarded, dtype: object

# %%
fare_boarded = data.groupby(["Boarded"])["Fare"].sum()

# %%
fare_boarded
# Out:
# Boarded
# Belfast           33.5000
# Cherbourg      15598.3294
# Queenstown      1244.1793
# Southampton    26332.6115
# Name: Fare, dtype: float64

# %%
fare_boarded.sum()
# Out:
# 43208.620200000005

# %%
fare_board = data.groupby(["Sex"])["Fare"].sum()

# %%
fare_board
# Out:
# Sex
# female    21528.3130
# male      22022.1739
# Name: Fare, dtype: float64

# %% [markdown]
# #### query

# %%
sex_age = data.query("Sex =='Age'")

# %%
sex_age
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, WikiId, Name_wiki, Age_wiki, Hometown, Boarded, Destination, Lifeboat, Body, Class]
# Index: []
#
# [0 rows x 21 columns]

# %%
sex_age = data.query("Sex =='Age'")

# %%
sex_age
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, WikiId, Name_wiki, Age_wiki, Hometown, Boarded, Destination, Lifeboat, Body, Class]
# Index: []
#
# [0 rows x 21 columns]

# %%
age_sex
# Out:
# Sex
# female    11130.59
# male      20125.08
# Name: Age, dtype: float64

# %%
age_sex
# Out:
# Sex
# female    11130.59
# male      20125.08
# Name: Age, dtype: float64

# %%
sex_boarded = data.groupby(["Sex"])["Boarded"].sum()

# %%
sex_boarder
# Out:
# Sex
# female    CherbourgSouthamptonSouthamptonSouthamptonCher...
# male      SouthamptonSouthamptonQueenstownSouthamptonSou...
# Name: Boarded, dtype: object

# %%
pclass_life = data.query("Pclass == 'Lifeboat'")

# %%
pclass_life
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, WikiId, Name_wiki, Age_wiki, Hometown, Boarded, Destination, Lifeboat, Body, Class]
# Index: []
#
# [0 rows x 21 columns]

# %%
data
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
age = data.query("Age == 24.0")
age
# Out:
#       PassengerId  Survived  Pclass  \
# 89             90       0.0       3
# 118           119       0.0       1
# 127           128       1.0       3
# 139           140       0.0       1
# 142           143       1.0       3
# 199           200       0.0       2
# 210           211       0.0       3
# 234           235       0.0       2
# 247           248       1.0       2
# 293           294       0.0       3
# 294           295       0.0       3
# 310           311       1.0       1
# 316           317       1.0       2
# 341           342       1.0       1
# 345           346       1.0       2
# 369           370       1.0       1
# 394           395       1.0       3
# 437           438       1.0       2
# 499           500       0.0       3
# 514           515       0.0       3
# 565           566       0.0       3
# 600           601       1.0       2
# 615           616       1.0       2
# 641           642       1.0       1
# 655           656       0.0       2
# ...

# %%
border_age = age.groupby(["Boarded"]).sum()

# %%
border_age
# Out:
#              PassengerId  Survived  Pclass    Age  SibSp  Parch      Fare  \
# Boarded
# Cherbourg           6254       5.0      14  240.0      3      5  741.9666
# Queenstown          3221       0.0       9   72.0      0      0   22.7500
# Southampton        21947      10.0      84  816.0     19     14  925.8125
#
#               WikiId  Age_wiki  Class
# Boarded
# Cherbourg     2389.0     240.0   14.0
# Queenstown    2563.0      73.0    9.0
# Southampton  23030.0     810.0   83.0

# %%
pclass_3 = data.query("Pclass == 3")

# %%
pclass_3
# Out:
#       PassengerId  Survived  Pclass                            Name     Sex  \
# 0               1       0.0       3         Braund, Mr. Owen Harris    male
# 2               3       1.0       3          Heikkinen, Miss. Laina  female
# 4               5       0.0       3        Allen, Mr. William Henry    male
# 5               6       0.0       3                Moran, Mr. James    male
# 7               8       0.0       3  Palsson, Master. Gosta Leonard    male
# ...           ...       ...     ...                             ...     ...
# 1303         1304       NaN       3  Henriksson, Miss. Jenny Lovisa  female
# 1304         1305       NaN       3              Spector, Mr. Woolf    male
# 1306         1307       NaN       3    Saether, Mr. Simon Sivertsen    male
# 1307         1308       NaN       3             Ware, Mr. Frederick    male
# 1308         1309       NaN       3        Peter, Master. Michael J    male
#
# ...

# %%
 = data.query("Sex == 'female'")female_survived

# %%
female_survived
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 8               9       1.0       3
# 9              10       1.0       2
# ...           ...       ...     ...
# 1300         1301       NaN       3
# 1301         1302       NaN       3
# 1302         1303       NaN       1
# 1303         1304       NaN       3
# 1305         1306       NaN       1
#
#                                                    Name     Sex   Age  SibSp  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                   Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ...

# %%
pclass_female = female_survived.query("Pclass == 3")

# %%
pclass_female
# Out:
#       PassengerId  Survived  Pclass  \
# 2               3       1.0       3
# 8               9       1.0       3
# 10             11       1.0       3
# 14             15       0.0       3
# 18             19       0.0       3
# ...           ...       ...     ...
# 1274         1275       NaN       3
# 1299         1300       NaN       3
# 1300         1301       NaN       3
# 1301         1302       NaN       3
# 1303         1304       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                      Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14                 Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 18    Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ...

# %%
southampton = female_survived.query("Boarded == 'Southampton'")

# %%
southampton
# Out:
#       PassengerId  Survived  Pclass  \
# 2               3       1.0       3
# 3               4       1.0       1
# 8               9       1.0       3
# 10             11       1.0       3
# 11             12       1.0       1
# ...           ...       ...     ...
# 1276         1277       NaN       2
# 1291         1292       NaN       1
# 1300         1301       NaN       3
# 1302         1303       NaN       1
# 1303         1304       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                      Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                             Bonnell, Miss. Elizabeth  female  58.0      0
# ...

# %%
survived = data.query("Sex == 'male'")

# %%
survived
# Out:
#       PassengerId  Survived  Pclass                            Name   Sex  \
# 0               1       0.0       3         Braund, Mr. Owen Harris  male
# 4               5       0.0       3        Allen, Mr. William Henry  male
# 5               6       0.0       3                Moran, Mr. James  male
# 6               7       0.0       1         McCarthy, Mr. Timothy J  male
# 7               8       0.0       3  Palsson, Master. Gosta Leonard  male
# ...           ...       ...     ...                             ...   ...
# 1298         1299       NaN       1      Widener, Mr. George Dunton  male
# 1304         1305       NaN       3              Spector, Mr. Woolf  male
# 1306         1307       NaN       3    Saether, Mr. Simon Sivertsen  male
# 1307         1308       NaN       3             Ware, Mr. Frederick  male
# 1308         1309       NaN       3        Peter, Master. Michael J  male
#
#        Age  SibSp  Parch              Ticket      Fare  ... Embarked  WikiId  \
# ...
